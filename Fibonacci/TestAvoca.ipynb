# %%
import pandas as pd
df = pd.read_csv("dataset/avocado.csv")
df['Date'] = pd.to_datetime(df["Date"])
albany_df = df[df['region'] == "Albany"]
albany_df.set_index("Date", inplace=True)
# print(albany_df)
albany_df["AveragePrice"].plot()

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()

# %%
albany_df.index
albany_df.sort_index(inplace=True)
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# print(albany_df.head(3))
albany_df["price25m"] = albany_df["AveragePrice"].rolling(25).mean()
# print(albany_df.head(3))
print(albany_df.tail(3))
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region  price25m
# Date
# 2018-03-18  conventional  2018  Albany    1.4276
# 2018-03-25  conventional  2018  Albany    1.4272
# 2018-03-25       organic  2018  Albany    1.4368
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(albany_df.dropna().head(3))
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
#
#             year  region  price25m
# Date
# 2015-03-29  2015  Albany    1.4660
# 2015-03-29  2015  Albany    1.4580
# 2015-04-05  2015  Albany    1.4328

# %%
albany_df = df.copy()[df['region'] == "Albany"]
albany_df.set_index("Date", inplace=True)
albany_df["price25mean"] = albany_df["AveragePrice"].rolling(25).mean()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
#
#                     type  year  region  price25mean
# Date
# 2015-12-27  conventional  2015  Albany          NaN
# 2015-12-20  conventional  2015  Albany          NaN
# 2015-12-13  conventional  2015  Albany          NaN

# %%
# print(df["region"].values.tolist())
print(set(df["region"].values.tolist()))
# Out:
# {'StLouis', 'GrandRapids', 'California', 'Syracuse', 'SanFrancisco', 'BaltimoreWashington', 'TotalUS', 'NewYork', 'HartfordSpringfield', 'Atlanta', 'Boise', 'Indianapolis', 'BuffaloRochester', 'Portland', 'PhoenixTucson', 'Houston', 'Albany', 'LosAngeles', 'HarrisburgScranton', 'WestTexNewMexico', 'SouthCentral', 'Northeast', 'SouthCarolina', 'Seattle', 'Detroit', 'RichmondNorfolk', 'LasVegas', 'Jacksonville', 'Louisville', 'GreatLakes', 'NorthernNewEngland', 'Orlando', 'RaleighGreensboro', 'Southeast', 'Charlotte', 'Midsouth', 'Denver', 'NewOrleansMobile', 'MiamiFtLauderdale', 'Spokane', 'West', 'Philadelphia', 'Chicago', 'CincinnatiDayton', 'Columbus', 'SanDiego', 'DallasFtWorth', 'Pittsburgh', 'Sacramento', 'Boston', 'Roanoke', 'Nashville', 'Plains', 'Tampa'}

# %%
print(df["region"].unique())
# Out:
# ['Albany' 'Atlanta' 'BaltimoreWashington' 'Boise' 'Boston'
#  'BuffaloRochester' 'California' 'Charlotte' 'Chicago' 'CincinnatiDayton'
#  'Columbus' 'DallasFtWorth' 'Denver' 'Detroit' 'GrandRapids' 'GreatLakes'
#  'HarrisburgScranton' 'HartfordSpringfield' 'Houston' 'Indianapolis'
#  'Jacksonville' 'LasVegas' 'LosAngeles' 'Louisville' 'MiamiFtLauderdale'
#  'Midsouth' 'Nashville' 'NewOrleansMobile' 'NewYork' 'Northeast'
#  'NorthernNewEngland' 'Orlando' 'Philadelphia' 'PhoenixTucson'
#  'Pittsburgh' 'Plains' 'Portland' 'RaleighGreensboro' 'RichmondNorfolk'
#  'Roanoke' 'Sacramento' 'SanDiego' 'SanFrancisco' 'Seattle'
#  'SouthCarolina' 'SouthCentral' 'Southeast' 'Spokane' 'StLouis' 'Syracuse'
#  'Tampa' 'TotalUS' 'West' 'WestTexNewMexico']

# %%
graphe_df = pd.DataFrame()

for region in df["region"].unique()[:16]:
    print(region)
    region_df = df.copy()[df["region"] == region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25mean"] = region_df["AveragePrice"].rolling(25).mean()
    
    if graphe_df.empty:
        graphe_df = region_df[[f"{region}_price25mean"]]
    else:
        graphe_df = graphe_df.join(region_df[f"{region}_price25mean"])
print(graphe_df.tail(3))
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes
#             Albany_price25mean  Atlanta_price25mean  \
# Date
# 2018-03-25              1.4368               1.2884
# 2018-03-25              1.4368               1.2884
# 2018-03-25              1.4368               1.2884
#
#             BaltimoreWashington_price25mean  Boise_price25mean  \
# Date
# 2018-03-25                           1.3844             1.5016
# 2018-03-25                           1.3844             1.5016
# 2018-03-25                           1.3844             1.5016
#
#             Boston_price25mean  BuffaloRochester_price25mean  \
# Date
# 2018-03-25               1.588                        1.2232
# 2018-03-25               1.588                        1.2232
# 2018-03-25               1.588                        1.2232
#
#             California_price25mean  Charlotte_price25mean  \
# Date
# 2018-03-25                  1.4232                 1.4916
# 2018-03-25                  1.4232                 1.4916
# 2018-03-25                  1.4232                 1.4916
#
#             Chicago_price25mean  CincinnatiDayton_price25mean  \
# Date
# 2018-03-25               1.5708                        1.2792
# 2018-03-25               1.5708                        1.2792
# 2018-03-25               1.5708                        1.2792
#
#             Columbus_price25mean  DallasFtWorth_price25mean  \
# Date
# 2018-03-25                1.1704                      1.118
# 2018-03-25                1.1704                      1.118
# 2018-03-25                1.1704                      1.118
#
#             Denver_price25mean  Detroit_price25mean  GrandRapids_price25mean  \
# Date
# 2018-03-25              1.2888               1.1728                   1.3164
# 2018-03-25              1.2888               1.1728                   1.3264
# 2018-03-25              1.2888               1.1728                   1.3264
#
#             GreatLakes_price25mean
# Date
# 2018-03-25                  1.2788
# 2018-03-25                  1.2568
# 2018-03-25                  1.2788

# %%
df = pd.read_csv("dataset/avocado.csv")
df = df.copy()[df['type'] == 'organic']
df["Date"] = pd.to_datetime(df["Date"])
df.sort_values(by="Date", ascending=True, inplace=True)
print(df.head())
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume       4046      4225  \
# 9489           51 2015-01-04          1.24     142349.77  107490.73  25711.96
# 10269          51 2015-01-04          1.50       6329.83    3730.80   2141.91
# 10893          51 2015-01-04          1.12      17296.85   14569.66   1868.59
# 9437           51 2015-01-04          1.73        379.82       0.00     59.82
# 11621          51 2015-01-04          1.30       5782.70     723.29   4221.15
# 10321          51 2015-01-04          1.25      54495.54   47721.51   1723.40
# 10841          51 2015-01-04          1.72       3788.60     384.30   1597.97
# 9385           51 2015-01-04          1.83       2192.13       8.66    939.43
# 11673          51 2015-01-04          1.80       3597.07    1552.48   1521.26
# 10373          51 2015-01-04          1.48       1395.75      12.41    824.64
#
#         4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 9489    2.93     9144.15     9144.15        0.00          0.0  organic  2015
# 10269   0.00      457.12      426.67       30.45          0.0  organic  2015
# 10893   0.00      858.60      830.00       28.60          0.0  organic  2015
# 9437    0.00      320.00      320.00        0.00          0.0  organic  2015
# 11621   0.00      838.26      223.33      614.93          0.0  organic  2015
# 10321   0.00     5050.63     5050.63        0.00          0.0  organic  2015
# 10841  11.42     1794.91     1794.91        0.00          0.0  organic  2015
# 9385    0.00     1244.04     1244.04        0.00          0.0  organic  2015
# 11673   0.00      523.33      523.33        0.00          0.0  organic  2015
# 10373   0.00      558.70      478.15       80.55          0.0  organic  2015
#
#                  region
# 9489         California
# 10269          LasVegas
# 10893     PhoenixTucson
# 9437   BuffaloRochester
# 11621           Spokane
# 10321        LosAngeles
# 10841      Philadelphia
# 9385             Boston
# 11673           StLouis
# 10373        Louisville

# %%
graphe_df = pd.DataFrame()

for region in df["region"].unique()[:16]:
    print(region)
    region_df = df.copy()[df["region"] == region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_price25mean"] = region_df["AveragePrice"].rolling(25).mean()
    
    if graphe_df.empty:
        graphe_df = region_df[[f"{region}_price25mean"]]
    else:
        graphe_df = graphe_df.join(region_df[f"{region}_price25mean"])
print(graphe_df.tail())
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
#             California_price25mean  LasVegas_price25mean  \
# Date
# 2018-02-25                  1.9128                1.9120
# 2018-03-04                  1.8876                1.8748
# 2018-03-11                  1.8636                1.8440
# 2018-03-18                  1.8516                1.8204
# 2018-03-25                  1.8364                1.7968
#
#             PhoenixTucson_price25mean  BuffaloRochester_price25mean  \
# Date
# 2018-02-25                     1.7468                        1.2912
# 2018-03-04                     1.7404                        1.2744
# 2018-03-11                     1.7324                        1.2652
# 2018-03-18                     1.7216                        1.2560
# 2018-03-25                     1.7104                        1.2416
#
#             Spokane_price25mean  LosAngeles_price25mean  \
# Date
# 2018-02-25               2.1544                  1.9024
# 2018-03-04               2.1040                  1.8656
# 2018-03-11               2.0552                  1.8284
# 2018-03-18               2.0012                  1.8160
# 2018-03-25               1.9496                  1.8016
#
#             Philadelphia_price25mean  Boston_price25mean  StLouis_price25mean  \
# Date
# 2018-02-25                    1.6324              1.7636               1.9240
# 2018-03-04                    1.6260              1.7708               1.8868
# 2018-03-11                    1.6300              1.7824               1.8468
# 2018-03-18                    1.6304              1.7932               1.8192
# 2018-03-25                    1.6256              1.7984               1.7976
#
#             Louisville_price25mean  Orlando_price25mean  \
# Date
# 2018-02-25                  1.7044               1.8728
# 2018-03-04                  1.6816               1.8512
# 2018-03-11                  1.6508               1.8004
# 2018-03-18                  1.6176               1.7712
# 2018-03-25                  1.5844               1.7352
#
#             Southeast_price25mean  Boise_price25mean  \
# Date
# 2018-02-25                 1.7116             2.0512
# 2018-03-04                 1.6868             2.0176
# 2018-03-11                 1.6484             1.9836
# 2018-03-18                 1.6156             1.9520
# 2018-03-25                 1.5820             1.9128
#
#             MiamiFtLauderdale_price25mean  NorthernNewEngland_price25mean  \
# Date
# 2018-02-25                         1.7140                          1.6280
# 2018-03-04                         1.7068                          1.6224
# 2018-03-11                         1.6904                          1.6264
# 2018-03-18                         1.6692                          1.6284
# 2018-03-25                         1.6392                          1.6312
#
#             BaltimoreWashington_price25mean
# Date
# 2018-02-25                           1.5836
# 2018-03-04                           1.5772
# 2018-03-11                           1.5732
# 2018-03-18                           1.5684
# 2018-03-25                           1.5568

# %%
graphe_df.plot(figsize=(8,5), legend=False)
